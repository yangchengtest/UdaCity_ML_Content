# %%
# %load explore_enron_data.py
#!/usr/bin/python

""" 
    Starter code for exploring the Enron dataset (emails + finances);
    loads up the dataset (pickled dict of dicts).

    The dataset has the form:
    enron_data["LASTNAME FIRSTNAME MIDDLEINITIAL"] = { features_dict }

    {features_dict} is a dictionary of features associated with that person.
    You should explore features_dict as part of the mini-project,
    but here's an example to get you started:

    enron_data["SKILLING JEFFREY K"]["bonus"] = 5600000
    
"""

import pickle
import sys;
sys.path.append("../final_project/") 
import poi_email_addresses as poiEmail

enron_data = pickle.load(open("../final_project/final_project_dataset.pkl", "r"))
enron_name = open("../final_project/poi_names.txt", "r").readlines()
enron_name_split=[]
for index in range(len(enron_name)):
    split=enron_name[index].split()
    if len(split)>2:
        enron_name_split.append(split)
print len(enron_name_split)
print len(enron_data)
print len(list(enron_data.values())[0])
poi_count=0
havesalary_count=0;
haveemail_count=0;
totalpayment_count=0;
for k,v in enron_data.iteritems():
    if enron_data[k]["poi"]==1:
        poi_count=poi_count+1
    if (v["email_address"]!='NaN'):
        haveemail_count=haveemail_count+1
    if (v["salary"]!='NaN'):
        havesalary_count=havesalary_count+1
    if (v["total_payments"]=='NaN'):
        totalpayment_count=totalpayment_count+1    
    keysplit=k.split()
    if (len(keysplit)<2):
        continue
    if ((keysplit[1]=="JAMES") and (keysplit[0]=="PRENTICE")):
        print "1",v
    if ((keysplit[1]=="WESLEY") and (keysplit[0]=="COLWELL")):
        print "2",v
    if ((keysplit[1]=="JEFFREY") and (keysplit[0]=="SKILLING")):
        print "3",v     
print haveemail_count,havesalary_count,totalpayment_count
print poi_count
poi_same_count=0
poi_email=poiEmail.poiEmails()
for k,v in enron_data.iteritems():
    isSame=False
    ksplit=k.split()
    if (len(ksplit)<2):
        continue
    for index in range(len(enron_name_split)):
        if ((ksplit[0]==enron_name_split[index][1][0:len(enron_name_split[index][1])-1].upper()) and (ksplit[1]==enron_name_split[index][2].upper())):
            print ksplit," ",enron_name_split[index]
            isSame=True
    if (isSame):
        poi_same_count=poi_same_count+1
print poi_same_count
# Out:
# 35
# 146
# 21
# 2 {'salary': 288542, 'to_messages': 1758, 'deferral_payments': 27610, 'total_payments': 1490344, 'exercised_stock_options': 'NaN', 'bonus': 1200000, 'restricted_stock': 698242, 'shared_receipt_with_poi': 1132, 'restricted_stock_deferred': 'NaN', 'total_stock_value': 698242, 'expenses': 16514, 'loan_advances': 'NaN', 'from_messages': 40, 'other': 101740, 'from_this_person_to_poi': 11, 'poi': True, 'director_fees': 'NaN', 'deferred_income': -144062, 'long_term_incentive': 'NaN', 'email_address': 'wes.colwell@enron.com', 'from_poi_to_this_person': 240}
# ...
